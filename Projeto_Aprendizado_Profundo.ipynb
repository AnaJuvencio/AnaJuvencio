# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaJuvencio/AnaJuvencio/blob/main/Projeto_Aprendizado_Profundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalação de Bibliotecas

# %%
# !pip install datasets tensorflow matplotlib scikit-learn
import tensorflow as tf

# %% [markdown]
# Carregando o dataset TrashNet

# %%
from datasets import load_dataset

ds = load_dataset("garythung/trashnet")

# %% [markdown]
# Conferir chave disponíveis

# %%
print(ds)
print(ds['train'][0])
